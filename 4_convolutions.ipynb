# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
imgsize = 28
n_labels = 10
n_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, imgsize, imgsize, n_channels)).astype(np.float32)
  labels = (np.arange(n_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
bsize = 16
psize = 5
depth = 16
n_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(bsize, imgsize, imgsize, n_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(bsize, n_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weight1 = tf.Variable(tf.truncated_normal(
                  [psize, psize, n_channels, depth], stddev=0.1))
  bias1 = tf.Variable(tf.zeros([depth]))
  
  weight2 = tf.Variable(tf.truncated_normal(
                  [psize, psize, depth, depth], stddev=0.1))
  bias2 = tf.Variable(tf.constant(1.0, shape=[depth]))
  
  weight3 = tf.Variable(tf.truncated_normal(
                  [imgsize // 4 * imgsize // 4 * depth, n_hidden], stddev=0.1))
  bias3 = tf.Variable(tf.constant(1.0, shape=[n_hidden]))
  
  weight4 = tf.Variable(tf.truncated_normal(
                  [n_hidden, n_labels], stddev=0.1))
  bias4 = tf.Variable(tf.constant(1.0, shape=[n_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, weight1, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + bias1)
    
    conv = tf.nn.conv2d(hidden, weight2, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + bias2)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, weight3) + bias3)
    
    return tf.matmul(hidden, weight4) + bias4
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
n_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Graph initialized')
  
  for step in range(n_steps):
    offset = (step * bsize) % (train_labels.shape[0] - bsize)
    
    batch_data = train_dataset[offset:(offset + bsize), :, :, :]
    batch_labels = train_labels[offset:(offset + bsize), :]
    
    dic = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
    _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=dic)
    
    if (step % 100 == 0):
      print('Step %d' % (step))
      print('Minibatch loss at: %.3f' % (l))
      print('Minibatch accuracy: %.2f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.2f%%' % accuracy(valid_prediction.eval(), valid_labels))
      
  print('Test accuracy: %.2f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Graph initialized
# Step 0
# Minibatch loss at: 3.470
# Minibatch accuracy: 6.25%
# Validation accuracy: 10.00%
# Step 100
# Minibatch loss at: 1.059
# Minibatch accuracy: 68.75%
# Validation accuracy: 70.27%
# Step 200
# Minibatch loss at: 1.763
# Minibatch accuracy: 68.75%
# Validation accuracy: 68.93%
# Step 300
# Minibatch loss at: 0.893
# Minibatch accuracy: 81.25%
# Validation accuracy: 79.77%
# Step 400
# Minibatch loss at: 0.758
# Minibatch accuracy: 75.00%
# Validation accuracy: 80.46%
# Step 500
# Minibatch loss at: 1.014
# Minibatch accuracy: 62.50%
# Validation accuracy: 80.12%
# Step 600
# Minibatch loss at: 0.619
# Minibatch accuracy: 81.25%
# Validation accuracy: 81.41%
# Step 700
# Minibatch loss at: 0.897
# Minibatch accuracy: 75.00%
# Validation accuracy: 81.42%
# Step 800
# Minibatch loss at: 0.468
# Minibatch accuracy: 81.25%
# Validation accuracy: 83.20%
# Step 900
# Minibatch loss at: 0.376
# Minibatch accuracy: 81.25%
# Validation accuracy: 82.03%
# Step 1000
# Minibatch loss at: 0.657
# Minibatch accuracy: 87.50%
# Validation accuracy: 82.41%
# Test accuracy: 88.37%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
bsize = 16 # batch size
psize = 5  # patch size
depth = 16
n_hidden = 64

# Variables.
def weight_variable(shape):
  init_val = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(init_val)

def bias_variable(shape,val):
  init_val = tf.constant(val, shape=shape)
  return tf.Variable(init_val)

# Model.
def layer_model(x, w, b):
  conv = tf.nn.conv2d(x, w, [1,1,1,1], padding='SAME') 
  conv = tf.nn.relu(conv + b)
  pool = tf.nn.max_pool(conv, [1,2,2,1], [1,2,2,1], padding='SAME')
  return pool

def mlp_network(data):
  pool1 = layer_model(data,  weight1, bias1) #(16,7,7,16) 
  pool2 = layer_model(pool1, weight2, bias2) #(16,2,2,16)
  
  d1,d2,d3,d4 = pool2.get_shape().as_list()
  pool2rs = tf.reshape(pool2, [d1, d2*d3*d4]) #(16,64)
  layer3 = tf.nn.relu(tf.matmul(pool2rs, weight3) + bias3)
    
  #pool3 = layer_model(pool2, weight3, bias3)
  #pool4 = layer_model(pool3, weight4, bias4)

  return tf.matmul(layer3, weight4) + bias4

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(bsize, imgsize, imgsize, n_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(bsize, n_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weight1 = weight_variable([psize, psize, n_channels, depth]) #(5,5,1,16)
  weight2 = weight_variable([psize, psize, depth, depth]) #(5,5,16,16)
  weight3 = weight_variable([(imgsize//4)* (imgsize//4)* depth, n_hidden]) #(784,64)
  weight4 = weight_variable([n_hidden, n_labels]) #(16,10)
  
  #bias1 = tf.Variable(tf.zeros([depth]))
  bias1 = bias_variable([depth], 0)      #(16,)
  bias2 = bias_variable([depth], 0.1)    #(16,)
  bias3 = bias_variable([n_hidden], 0.1) #(64,)
  bias4 = bias_variable([n_labels], 0.1) #(10,)
  
  # Training computation.
  logits = mlp_network(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits,tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
n_steps = 2001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Graph initialized')
  
  for step in range(n_steps):
    offset = (step * bsize) % (train_labels.shape[0] - bsize)
    
    batch_data = train_dataset[offset:(offset + bsize), :, :, :]
    batch_labels = train_labels[offset:(offset + bsize), :]
    
    dic = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
    _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=dic)
    
    if (step % 400 == 0):
      print('Step %d' % (step))
      print('Minibatch loss: %.3f' % (l))
      print('Minibatch accuracy: %.2f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.2f%%' % accuracy(valid_prediction.eval(), valid_labels))
      
  print('Test accuracy: %.2f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Graph initialized
# Step 0
# Minibatch loss: 2.271
# Minibatch accuracy: 6.25%
# Validation accuracy: 12.07%
# Step 400
# Minibatch loss: 0.541
# Minibatch accuracy: 81.25%
# Validation accuracy: 70.74%
# Step 800
# Minibatch loss: 0.486
# Minibatch accuracy: 87.50%
# Validation accuracy: 74.22%
# Step 1200
# Minibatch loss: 0.486
# Minibatch accuracy: 81.25%
# Validation accuracy: 76.59%
# Step 1600
# Minibatch loss: 0.248
# Minibatch accuracy: 87.50%
# Validation accuracy: 76.49%
# Step 2000
# Minibatch loss: 0.416
# Minibatch accuracy: 87.50%
# Validation accuracy: 75.27%
# Test accuracy: 81.00%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
bsize = 16 # batch size
psize = 5  # patch size
depth = 16
n_hidden = 64
size3 = ((imgsize-psize + 1) // 2 - psize + 1) // 2  #4

# Variables.
def weight_variable(shape):
  init_val = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(init_val)

def bias_variable(shape, val):
  if val==0:
    init_val = tf.zeros([depth])
  else:
    init_val = tf.constant(val, shape=shape)
  return tf.Variable(init_val)

# Model.
def layer_model(x, w, b):
  conv = tf.nn.conv2d(x, w, [1,1,1,1], padding='VALID') 
  conv = tf.nn.relu(conv + b)
  pool = tf.nn.avg_pool(conv, [1,2,2,1], [1,2,2,1], padding='VALID')
  return pool

def conv_net(data):
  pool1 = layer_model(data,  weight1, bias1) #(16,7,7,16) 
  pool2 = layer_model(pool1, weight2, bias2) #(16,2,2,16)
  
  d1,d2,d3,d4 = pool2.get_shape().as_list()
  pool2rs = tf.reshape(pool2, [d1, d2*d3*d4]) #(16,64)
  layer3 = tf.nn.relu(tf.matmul(pool2rs, weight3) + bias3)

  return tf.matmul(layer3, weight4) + bias4

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(bsize, imgsize, imgsize, n_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(bsize, n_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weight1 = weight_variable([psize, psize, n_channels, depth]) #(5,5,1,16)
  weight2 = weight_variable([psize, psize, depth, depth]) #(5,5,16,16)
  weight3 = weight_variable([size3* size3* depth, n_hidden]) #(64,64)
  weight4 = weight_variable([n_hidden, n_labels]) #(16,10)
  
  bias1 = bias_variable([depth], 0)     #(16,)
  bias2 = bias_variable([depth], 1.0)    #(16,)
  bias3 = bias_variable([n_hidden], 1.0) #(64,)
  bias4 = bias_variable([n_labels], 1.0) #(10,)
  
  # Training computation.
  logits = conv_net(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits,tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
n_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Graph initialized')
  
  for step in range(n_steps):
    offset = (step * bsize) % (train_labels.shape[0] - bsize)
    
    batch_data = train_dataset[offset:(offset + bsize), :, :, :]
    batch_labels = train_labels[offset:(offset + bsize), :]
    
    dic = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
    _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=dic)
    
    if (step % 400 == 0):
      print('Step %d' % (step))
      print('Minibatch loss: %.3f' % (l))
      print('Minibatch accuracy: %.2f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.2f%%' % accuracy(valid_prediction.eval(), valid_labels))
      
  print('Test accuracy: %.2f%%' % accuracy(test_prediction.eval(), test_labels))
  print('Done.')
# Out:
# Graph initialized
# Step 0
# Minibatch loss: 2.385
# Minibatch accuracy: 0.00%
# Validation accuracy: 10.00%
# Step 400
# Minibatch loss: 0.731
# Minibatch accuracy: 75.00%
# Validation accuracy: 76.71%
# Step 800
# Minibatch loss: 0.659
# Minibatch accuracy: 81.25%
# Validation accuracy: 81.49%
# Step 1200
# Minibatch loss: 0.588
# Minibatch accuracy: 81.25%
# Validation accuracy: 81.77%
# Step 1600
# Minibatch loss: 0.681
# Minibatch accuracy: 87.50%
# Validation accuracy: 83.20%
# Step 2000
# Minibatch loss: 0.610
# Minibatch accuracy: 87.50%
# Validation accuracy: 84.67%
# Step 2400
# Minibatch loss: 0.532
# Minibatch accuracy: 81.25%
# Validation accuracy: 84.51%
# Step 2800
# Minibatch loss: 0.462
# Minibatch accuracy: 81.25%
# Validation accuracy: 85.30%
# Step 3200
# Minibatch loss: 0.317
# Minibatch accuracy: 87.50%
# Validation accuracy: 85.84%
# Step 3600
# Minibatch loss: 0.789
# Minibatch accuracy: 68.75%
# Validation accuracy: 87.00%
# Step 4000
# Minibatch loss: 0.933
# Minibatch accuracy: 81.25%
# Validation accuracy: 86.96%
# Step 4400
# Minibatch loss: 0.473
# Minibatch accuracy: 87.50%
# Validation accuracy: 86.48%
# Step 4800
# Minibatch loss: 0.289
# Minibatch accuracy: 87.50%
# Validation accuracy: 86.79%
# Step 5200
# Minibatch loss: 0.233
# Minibatch accuracy: 87.50%
# Validation accuracy: 86.77%
# Step 5600
# Minibatch loss: 0.113
# Minibatch accuracy: 100.00%
# Validation accuracy: 87.44%
# Step 6000
# Minibatch loss: 0.360
# Minibatch accuracy: 93.75%
# Validation accuracy: 87.17%
# Step 6400
# Minibatch loss: 0.612
# Minibatch accuracy: 87.50%
# Validation accuracy: 87.68%
# Step 6800
# Minibatch loss: 0.596
# Minibatch accuracy: 75.00%
# Validation accuracy: 88.39%
# Step 7200
# Minibatch loss: 0.521
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.01%
# Step 7600
# Minibatch loss: 0.299
# Minibatch accuracy: 93.75%
# Validation accuracy: 88.31%
# Step 8000
# Minibatch loss: 0.929
# Minibatch accuracy: 62.50%
# Validation accuracy: 87.80%
# Step 8400
# Minibatch loss: 0.086
# Minibatch accuracy: 93.75%
# Validation accuracy: 88.20%
# Step 8800
# Minibatch loss: 0.590
# Minibatch accuracy: 75.00%
# Validation accuracy: 88.49%
# Step 9200
# Minibatch loss: 0.568
# Minibatch accuracy: 81.25%
# Validation accuracy: 88.51%
# Step 9600
# Minibatch loss: 0.417
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.66%
# Step 10000
# Minibatch loss: 0.258
# Minibatch accuracy: 93.75%
# Validation accuracy: 88.70%
# Step 10400
# Minibatch loss: 0.062
# Minibatch accuracy: 100.00%
# Validation accuracy: 88.76%
# Step 10800
# Minibatch loss: 0.049
# Minibatch accuracy: 100.00%
# Validation accuracy: 89.10%
# Step 11200
# Minibatch loss: 0.306
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.91%
# Step 11600
# Minibatch loss: 0.248
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.65%
# Step 12000
# Minibatch loss: 0.412
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.81%
# Step 12400
# Minibatch loss: 0.346
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.75%
# Step 12800
# Minibatch loss: 0.729
# Minibatch accuracy: 81.25%
# Validation accuracy: 88.82%
# Step 13200
# Minibatch loss: 0.422
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.09%
# Step 13600
# Minibatch loss: 0.427
# Minibatch accuracy: 87.50%
# Validation accuracy: 88.99%
# Step 14000
# Minibatch loss: 0.355
# Minibatch accuracy: 81.25%
# Validation accuracy: 89.31%
# Step 14400
# Minibatch loss: 0.015
# Minibatch accuracy: 100.00%
# Validation accuracy: 89.00%
# Step 14800
# Minibatch loss: 0.226
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.26%
# Step 15200
# Minibatch loss: 0.422
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.27%
# Step 15600
# Minibatch loss: 0.208
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.35%
# Step 16000
# Minibatch loss: 0.387
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.62%
# Step 16400
# Minibatch loss: 0.424
# Minibatch accuracy: 75.00%
# Validation accuracy: 89.34%
# Step 16800
# Minibatch loss: 0.802
# Minibatch accuracy: 81.25%
# Validation accuracy: 89.77%
# Step 17200
# Minibatch loss: 0.384
# Minibatch accuracy: 81.25%
# Validation accuracy: 89.45%
# Step 17600
# Minibatch loss: 0.693
# Minibatch accuracy: 81.25%
# Validation accuracy: 89.33%
# Step 18000
# Minibatch loss: 0.272
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.74%
# Step 18400
# Minibatch loss: 0.186
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.47%
# Step 18800
# Minibatch loss: 0.041
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.14%
# Step 19200
# Minibatch loss: 0.316
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.85%
# Step 19600
# Minibatch loss: 0.512
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.72%
# Step 20000
# Minibatch loss: 0.355
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.90%
# Step 20400
# Minibatch loss: 0.382
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.06%
# Step 20800
# Minibatch loss: 0.276
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.83%
# Step 21200
# Minibatch loss: 0.157
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.00%
# Step 21600
# Minibatch loss: 0.386
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.98%
# Step 22000
# Minibatch loss: 0.553
# Minibatch accuracy: 75.00%
# Validation accuracy: 89.73%
# Step 22400
# Minibatch loss: 0.165
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.18%
# Step 22800
# Minibatch loss: 0.258
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.86%
# Step 23200
# Minibatch loss: 0.347
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.10%
# Step 23600
# Minibatch loss: 0.156
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.95%
# Step 24000
# Minibatch loss: 0.414
# Minibatch accuracy: 87.50%
# Validation accuracy: 89.90%
# Step 24400
# Minibatch loss: 0.318
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.02%
# Step 24800
# Minibatch loss: 0.055
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.23%
# Step 25200
# Minibatch loss: 0.375
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.10%
# Step 25600
# Minibatch loss: 0.460
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.27%
# Step 26000
# Minibatch loss: 0.232
# Minibatch accuracy: 93.75%
# Validation accuracy: 89.96%
# Step 26400
# Minibatch loss: 0.477
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.13%
# Step 26800
# Minibatch loss: 0.212
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.14%
# Step 27200
# Minibatch loss: 0.392
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.11%
# Step 27600
# Minibatch loss: 0.072
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.31%
# Step 28000
# Minibatch loss: 0.032
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.43%
# Step 28400
# Minibatch loss: 0.474
# Minibatch accuracy: 75.00%
# Validation accuracy: 90.38%
# Step 28800
# Minibatch loss: 0.061
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.45%
# Step 29200
# Minibatch loss: 0.238
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.02%
# Step 29600
# Minibatch loss: 0.277
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.02%
# Step 30000
# Minibatch loss: 0.264
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.54%
# Step 30400
# Minibatch loss: 0.598
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.33%
# Step 30800
# Minibatch loss: 0.603
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.58%
# Step 31200
# Minibatch loss: 0.982
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.20%
# Step 31600
# Minibatch loss: 0.370
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.50%
# Step 32000
# Minibatch loss: 0.251
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.31%
# Step 32400
# Minibatch loss: 0.176
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.30%
# Step 32800
# Minibatch loss: 0.146
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.60%
# Step 33200
# Minibatch loss: 0.780
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.46%
# Step 33600
# Minibatch loss: 0.264
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.62%
# Step 34000
# Minibatch loss: 0.667
# Minibatch accuracy: 75.00%
# Validation accuracy: 90.63%
# Step 34400
# Minibatch loss: 0.117
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.76%
# Step 34800
# Minibatch loss: 0.229
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.28%
# Step 35200
# Minibatch loss: 0.689
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.80%
# Step 35600
# Minibatch loss: 0.195
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.65%
# Step 36000
# Minibatch loss: 0.178
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.61%
# Step 36400
# Minibatch loss: 0.284
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.59%
# Step 36800
# Minibatch loss: 0.793
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.49%
# Step 37200
# Minibatch loss: 0.269
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.67%
# Step 37600
# Minibatch loss: 0.371
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.75%
# Step 38000
# Minibatch loss: 0.219
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.71%
# Step 38400
# Minibatch loss: 0.235
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.39%
# Step 38800
# Minibatch loss: 0.217
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.36%
# Step 39200
# Minibatch loss: 0.323
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.80%
# Step 39600
# Minibatch loss: 0.040
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.81%
# Step 40000
# Minibatch loss: 0.028
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.63%
# Step 40400
# Minibatch loss: 0.745
# Minibatch accuracy: 75.00%
# Validation accuracy: 90.87%
# Step 40800
# Minibatch loss: 0.296
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.96%
# Step 41200
# Minibatch loss: 0.041
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.06%
# Step 41600
# Minibatch loss: 0.603
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.83%
# Step 42000
# Minibatch loss: 0.043
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.04%
# Step 42400
# Minibatch loss: 0.393
# Minibatch accuracy: 81.25%
# Validation accuracy: 90.58%
# Step 42800
# Minibatch loss: 0.558
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.91%
# Step 43200
# Minibatch loss: 0.112
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.31%
# Step 43600
# Minibatch loss: 0.271
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.22%
# Step 44000
# Minibatch loss: 0.095
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.93%
# Step 44400
# Minibatch loss: 0.042
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.83%
# Step 44800
# Minibatch loss: 0.033
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.06%
# Step 45200
# Minibatch loss: 0.149
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.91%
# Step 45600
# Minibatch loss: 0.020
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.62%
# Step 46000
# Minibatch loss: 0.213
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.13%
# Step 46400
# Minibatch loss: 0.271
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.57%
# Step 46800
# Minibatch loss: 0.292
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.10%
# Step 47200
# Minibatch loss: 0.099
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.99%
# Step 47600
# Minibatch loss: 0.073
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.64%
# Step 48000
# Minibatch loss: 0.247
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.92%
# Step 48400
# Minibatch loss: 0.283
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.05%
# Step 48800
# Minibatch loss: 0.196
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.99%
# Step 49200
# Minibatch loss: 0.183
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.78%
# Step 49600
# Minibatch loss: 0.372
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.96%
# Step 50000
# Minibatch loss: 0.797
# Minibatch accuracy: 75.00%
# Validation accuracy: 91.03%
# Step 50400
# Minibatch loss: 0.528
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.17%
# Step 50800
# Minibatch loss: 0.328
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.81%
# Step 51200
# Minibatch loss: 0.529
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.87%
# Step 51600
# Minibatch loss: 0.149
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.07%
# Step 52000
# Minibatch loss: 0.194
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.08%
# Step 52400
# Minibatch loss: 0.674
# Minibatch accuracy: 75.00%
# Validation accuracy: 90.83%
# Step 52800
# Minibatch loss: 0.495
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.95%
# Step 53200
# Minibatch loss: 0.026
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.90%
# Step 53600
# Minibatch loss: 0.287
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.16%
# Step 54000
# Minibatch loss: 0.341
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.21%
# Step 54400
# Minibatch loss: 0.010
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.99%
# Step 54800
# Minibatch loss: 0.300
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.01%
# Step 55200
# Minibatch loss: 0.072
# Minibatch accuracy: 100.00%
# Validation accuracy: 90.95%
# Step 55600
# Minibatch loss: 0.154
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.15%
# Step 56000
# Minibatch loss: 0.308
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.97%
# Step 56400
# Minibatch loss: 0.010
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.20%
# Step 56800
# Minibatch loss: 0.489
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.28%
# Step 57200
# Minibatch loss: 0.048
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.13%
# Step 57600
# Minibatch loss: 0.319
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.23%
# Step 58000
# Minibatch loss: 0.418
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.03%
# Step 58400
# Minibatch loss: 0.087
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.91%
# Step 58800
# Minibatch loss: 0.147
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.06%
# Step 59200
# Minibatch loss: 0.241
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.02%
# Step 59600
# Minibatch loss: 0.012
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.03%
# Step 60000
# Minibatch loss: 0.385
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.39%
# Step 60400
# Minibatch loss: 0.243
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.44%
# Step 60800
# Minibatch loss: 0.033
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.06%
# Step 61200
# Minibatch loss: 1.042
# Minibatch accuracy: 75.00%
# Validation accuracy: 91.17%
# Step 61600
# Minibatch loss: 0.287
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.81%
# Step 62000
# Minibatch loss: 0.219
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.08%
# Step 62400
# Minibatch loss: 0.124
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.05%
# Step 62800
# Minibatch loss: 0.316
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.25%
# Step 63200
# Minibatch loss: 0.109
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.84%
# Step 63600
# Minibatch loss: 0.471
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.82%
# Step 64000
# Minibatch loss: 0.504
# Minibatch accuracy: 75.00%
# Validation accuracy: 91.26%
# Step 64400
# Minibatch loss: 0.196
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.21%
# Step 64800
# Minibatch loss: 0.008
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.27%
# Step 65200
# Minibatch loss: 0.386
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.19%
# Step 65600
# Minibatch loss: 0.276
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.13%
# Step 66000
# Minibatch loss: 0.288
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.34%
# Step 66400
# Minibatch loss: 0.240
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.29%
# Step 66800
# Minibatch loss: 0.025
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.15%
# Step 67200
# Minibatch loss: 0.094
# Minibatch accuracy: 93.75%
# Validation accuracy: 90.97%
# Step 67600
# Minibatch loss: 0.486
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.04%
# Step 68000
# Minibatch loss: 0.179
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.21%
# Step 68400
# Minibatch loss: 0.275
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.09%
# Step 68800
# Minibatch loss: 0.007
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.14%
# Step 69200
# Minibatch loss: 0.178
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.20%
# Step 69600
# Minibatch loss: 0.290
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.18%
# Step 70000
# Minibatch loss: 0.512
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.46%
# Step 70400
# Minibatch loss: 0.364
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.11%
# Step 70800
# Minibatch loss: 0.296
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.16%
# Step 71200
# Minibatch loss: 0.296
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.12%
# Step 71600
# Minibatch loss: 0.369
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.39%
# Step 72000
# Minibatch loss: 0.296
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.07%
# Step 72400
# Minibatch loss: 0.281
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.44%
# Step 72800
# Minibatch loss: 0.433
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.62%
# Step 73200
# Minibatch loss: 0.595
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.34%
# Step 73600
# Minibatch loss: 0.819
# Minibatch accuracy: 75.00%
# Validation accuracy: 91.52%
# Step 74000
# Minibatch loss: 0.332
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.38%
# Step 74400
# Minibatch loss: 0.604
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.23%
# Step 74800
# Minibatch loss: 0.386
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.06%
# Step 75200
# Minibatch loss: 0.507
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.09%
# Step 75600
# Minibatch loss: 0.152
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.20%
# Step 76000
# Minibatch loss: 0.294
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.16%
# Step 76400
# Minibatch loss: 0.139
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.15%
# Step 76800
# Minibatch loss: 0.466
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.10%
# Step 77200
# Minibatch loss: 0.032
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.27%
# Step 77600
# Minibatch loss: 0.441
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.22%
# Step 78000
# Minibatch loss: 0.277
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.07%
# Step 78400
# Minibatch loss: 0.337
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.38%
# Step 78800
# Minibatch loss: 0.268
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.47%
# Step 79200
# Minibatch loss: 0.289
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.71%
# Step 79600
# Minibatch loss: 0.373
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.20%
# Step 80000
# Minibatch loss: 0.182
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.84%
# Step 80400
# Minibatch loss: 0.076
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.18%
# Step 80800
# Minibatch loss: 0.300
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.08%
# Step 81200
# Minibatch loss: 0.286
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.51%
# Step 81600
# Minibatch loss: 0.273
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.50%
# Step 82000
# Minibatch loss: 0.073
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.26%
# Step 82400
# Minibatch loss: 0.050
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.31%
# Step 82800
# Minibatch loss: 0.210
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.16%
# Step 83200
# Minibatch loss: 0.124
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.35%
# Step 83600
# Minibatch loss: 0.356
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.63%
# Step 84000
# Minibatch loss: 0.343
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.41%
# Step 84400
# Minibatch loss: 0.149
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.36%
# Step 84800
# Minibatch loss: 0.224
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.39%
# Step 85200
# Minibatch loss: 0.011
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.59%
# Step 85600
# Minibatch loss: 0.054
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.53%
# Step 86000
# Minibatch loss: 0.141
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.26%
# Step 86400
# Minibatch loss: 0.410
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.31%
# Step 86800
# Minibatch loss: 0.102
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.61%
# Step 87200
# Minibatch loss: 0.213
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.52%
# Step 87600
# Minibatch loss: 0.064
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.45%
# Step 88000
# Minibatch loss: 0.225
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.40%
# Step 88400
# Minibatch loss: 0.061
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.11%
# Step 88800
# Minibatch loss: 0.165
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.32%
# Step 89200
# Minibatch loss: 0.134
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.53%
# Step 89600
# Minibatch loss: 0.234
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.45%
# Step 90000
# Minibatch loss: 0.358
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.36%
# Step 90400
# Minibatch loss: 0.145
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.45%
# Step 90800
# Minibatch loss: 0.052
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.56%
# Step 91200
# Minibatch loss: 0.715
# Minibatch accuracy: 75.00%
# Validation accuracy: 91.64%
# Step 91600
# Minibatch loss: 0.160
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.45%
# Step 92000
# Minibatch loss: 0.342
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.48%
# Step 92400
# Minibatch loss: 0.665
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.02%
# Step 92800
# Minibatch loss: 0.194
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.31%
# Step 93200
# Minibatch loss: 0.317
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.28%
# Step 93600
# Minibatch loss: 0.206
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.53%
# Step 94000
# Minibatch loss: 0.140
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.35%
# Step 94400
# Minibatch loss: 0.274
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.20%
# Step 94800
# Minibatch loss: 0.826
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.18%
# Step 95200
# Minibatch loss: 0.074
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.67%
# Step 95600
# Minibatch loss: 0.197
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.32%
# Step 96000
# Minibatch loss: 0.242
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.66%
# Step 96400
# Minibatch loss: 0.241
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.16%
# Step 96800
# Minibatch loss: 0.025
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.68%
# Step 97200
# Minibatch loss: 0.139
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.38%
# Step 97600
# Minibatch loss: 0.495
# Minibatch accuracy: 81.25%
# Validation accuracy: 91.40%
# Step 98000
# Minibatch loss: 0.292
# Minibatch accuracy: 87.50%
# Validation accuracy: 90.37%
# Step 98400
# Minibatch loss: 0.175
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.45%
# Step 98800
# Minibatch loss: 0.257
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.54%
# Step 99200
# Minibatch loss: 0.109
# Minibatch accuracy: 100.00%
# Validation accuracy: 91.58%
# Step 99600
# Minibatch loss: 0.552
# Minibatch accuracy: 87.50%
# Validation accuracy: 91.33%
# Step 100000
# Minibatch loss: 0.302
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.68%
# Test accuracy: 95.64%
# Done.
