# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
    
  statinfo = os.stat(filename)
  
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d (words)' % len(words))
# Out:
# Data size 17005207 (words)

# %%
# check the data structure of words
print('First 100 words:')
print(words[:100])
# Out:
# First 100 words:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  data = list()
  unk_count = 0
  
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  
  return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)

print('Most common words (+UNK)\n', count[:10])
print('Sample data\n\n', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK)
#  [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
#
# Sample data
#  [5234, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
print('Dictionary items (10):')
print(list(dictionary.items())[:10])

print('\nReverse dictionary items (10):')
print(list(reverse_dictionary.items())[:10])
# Out:
# Dictionary items (10):
# [('dill', 34948), ('minsk', 18967), ('cta', 46500), ('tentacle', 22803), ('painstaking', 34690), ('contradict', 14592), ('natal', 18658), ('filled', 3064), ('treat', 4368), ('reflected', 3819)]
#
# Reverse dictionary items (10):
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for n_skips, swindow in [(2,1), (4,2)]:
    data_index = 0
    batch, labels = generate_batch(8, n_skips, swindow)
    print('\nwith num_skips = %d, skip_window = %d:' % (n_skips, swindow))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2, skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4, skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Graph initialized')
  average_loss = 0
  loss_skipgram = []
  
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_skipgram.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Graph initialized
# Average loss at step 0: 7.921136
# Nearest to was: shunning, polyhedron, lachaise, headmaster, dusty, tracer, semantics, ranches,
# Nearest to by: tuff, adjustment, workprint, ivory, immediate, agonists, symphonies, document,
# Nearest to also: mahathir, aspartic, scandinavians, exam, cunning, packaged, brigade, nhk,
# Nearest to no: kilmister, erwin, mustard, lesson, caters, leaflet, emanations, anchor,
# Nearest to or: journalistic, animations, lockwood, thereabouts, alfalfa, premises, bfi, boaz,
# Nearest to are: bahamian, infidel, arden, notate, adequate, moonshine, undoing, tatar,
# Nearest to that: qdos, bottlers, encephalitis, prost, wondering, inventing, illness, rearranged,
# Nearest to and: pipe, stig, aggressiveness, roadmap, beverly, biotechnology, depose, sociology,
# Nearest to new: unchecked, commonsense, rehabilitated, gaeltacht, dictating, peculiarly, alcott, midas,
# Nearest to during: rainforests, filthy, normans, essentials, waff, degenerate, efficacious, upcoming,
# Nearest to american: frantz, improvisations, speciation, gaborone, ovation, dehydrated, homeopaths, feroze,
# Nearest to five: onset, nyc, vertebra, boyhood, prerequisite, placenames, jacobins, debating,
# Nearest to world: recaptured, pernambuco, derleth, reviled, lyons, insisting, directrix, abrupt,
# Nearest to most: circumnavigated, centralisation, alban, sayer, scuola, quadrant, healey, battleships,
# Nearest to used: under, ule, influences, tien, tanks, skyway, mirabilis, weapons,
# Nearest to united: gamemasters, hegel, grist, selfish, burgundians, denarius, tokens, panasonic,
# Average loss at step 2000: 4.357030
# Average loss at step 4000: 3.865088
# Average loss at step 6000: 3.786603
# Average loss at step 8000: 3.680992
# Average loss at step 10000: 3.616284
# Nearest to was: is, had, has, were, by, be, prequels, been,
# Nearest to by: was, be, with, disguise, on, steady, lifeforms, brassiere,
# Nearest to also: often, which, brigade, playoffs, it, actually, degrees, girardeau,
# Nearest to no: kilmister, precolonial, lexicography, flanks, tool, performed, a, rivera,
# Nearest to or: and, endless, sociology, quimby, shall, gul, animations, sled,
# Nearest to are: were, is, be, have, include, nos, lothar, marlon,
# Nearest to that: which, it, kolbin, this, mckenzie, off, laude, fgm,
# Nearest to and: or, rotated, but, in, s, he, verb, neutralize,
# Nearest to new: southwestern, midas, overlapped, entitled, semantics, hrer, commonsense, cva,
# Nearest to during: labour, essentials, in, rainforests, docking, degenerate, eamon, mamre,
# Nearest to american: backed, provision, precinct, ghost, grigori, linehan, ketubah, gymnastics,
# Nearest to five: six, four, eight, seven, nine, three, zero, two,
# Nearest to world: recaptured, derleth, ko, pernambuco, belizean, recognising, photos, insisting,
# Nearest to most: circumnavigated, saturn, breakthrough, crosses, categorical, ireann, compensatory, quadrant,
# Nearest to used: skyway, multilinear, speak, studios, ule, deeply, tien, known,
# Nearest to united: grist, gamemasters, selfish, retracted, denarius, aeronautics, burgundians, richter,
# Average loss at step 12000: 3.604345
# Average loss at step 14000: 3.568327
# Average loss at step 16000: 3.408877
# Average loss at step 18000: 3.457772
# Average loss at step 20000: 3.540922
# Nearest to was: is, has, had, were, became, be, manned, are,
# Nearest to by: be, disguise, with, was, for, been, goidelic, when,
# Nearest to also: often, actually, never, which, usually, frequently, it, quickly,
# Nearest to no: kilmister, a, lexicography, inklings, any, austral, precolonial, abdul,
# Nearest to or: and, than, rivaling, shall, gul, bendis, felsic, freikorps,
# Nearest to are: were, is, have, but, was, nos, correlates, other,
# Nearest to that: which, however, but, sqrat, laude, off, descended, this,
# Nearest to and: or, but, stirrup, like, in, through, from, which,
# Nearest to new: midas, southwestern, winthrop, semantics, commonsense, cva, timetable, inherits,
# Nearest to during: under, in, after, same, outside, beef, labour, eamon,
# Nearest to american: british, french, bowling, precinct, minbari, linehan, english, bezier,
# Nearest to five: four, six, seven, three, zero, eight, two, nine,
# Nearest to world: derleth, insisting, recaptured, identity, dun, belizean, hematite, ko,
# Nearest to most: more, some, circumnavigated, many, saturn, categorical, crosses, breakthrough,
# Nearest to used: skyway, known, published, speak, coloured, referred, grau, antlers,
# Nearest to united: grist, gamemasters, wali, title, richter, denarius, retracted, holy,
# Average loss at step 22000: 3.499782
# Average loss at step 24000: 3.490130
# Average loss at step 26000: 3.478133
# Average loss at step 28000: 3.479455
# Average loss at step 30000: 3.503062
# Nearest to was: is, had, were, has, became, been, when, be,
# Nearest to by: from, in, under, as, when, massey, during, adjustment,
# Nearest to also: actually, often, which, it, never, generally, sometimes, quickly,
# Nearest to no: any, lexicography, austral, kilmister, a, only, metaphoric, inklings,
# Nearest to or: and, rivaling, than, zoning, wooded, bendis, documenting, tierney,
# Nearest to are: were, is, have, include, those, be, wtoo, these,
# Nearest to that: which, however, what, but, this, grievance, mah, mckenzie,
# Nearest to and: or, but, in, stirrup, through, mahendra, from, of,
# Nearest to new: midas, second, hospitals, southwestern, winthrop, inherits, hrer, photography,
# Nearest to during: in, after, under, at, outside, imposing, labour, when,
# Nearest to american: british, german, french, english, bowling, precinct, minbari, australian,
# Nearest to five: four, three, eight, six, seven, zero, nine, two,
# Nearest to world: insisting, derleth, identity, hematite, dun, omits, recaptured, belizean,
# Nearest to most: more, many, some, saturn, categorical, circumnavigated, among, receding,
# Nearest to used: known, responsible, published, skyway, referred, available, written, videotape,
# Nearest to united: grist, gamemasters, awm, wali, title, richter, retracted, denarius,
# Average loss at step 32000: 3.499908
# Average loss at step 34000: 3.494172
# Average loss at step 36000: 3.451968
# Average loss at step 38000: 3.302591
# Average loss at step 40000: 3.423734
# Nearest to was: is, has, had, were, became, been, be, by,
# Nearest to by: when, was, polk, with, be, as, locally, wealthiest,
# Nearest to also: which, often, increasingly, actually, usually, never, now, sometimes,
# Nearest to no: any, lexicography, austral, only, kilmister, inklings, gabrielle, metaphoric,
# Nearest to or: and, than, hatton, passenger, rivaling, troubleshooting, gul, t,
# Nearest to are: were, is, have, be, these, include, but, those,
# Nearest to that: which, however, this, what, laude, renminbi, when, sqrat,
# Nearest to and: or, like, but, in, practically, t, bachchan, fiji,
# Nearest to new: southwestern, winthrop, komodo, inherits, fences, plated, hospitals, kimchi,
# Nearest to during: in, under, after, outside, at, imposing, on, dub,
# Nearest to american: british, bowling, german, english, australian, russian, french, disallow,
# Nearest to five: seven, six, four, three, two, zero, eight, nine,
# Nearest to world: insisting, martins, dun, derleth, identity, sse, hematite, monopolist,
# Nearest to most: more, many, among, some, less, choi, saturn, several,
# Nearest to used: known, responsible, available, referred, published, found, written, considered,
# Nearest to united: grist, awm, richter, wali, gamemasters, burgundians, urine, crackdown,
# Average loss at step 42000: 3.433871
# Average loss at step 44000: 3.450769
# Average loss at step 46000: 3.449616
# Average loss at step 48000: 3.356193
# Average loss at step 50000: 3.376892
# Nearest to was: is, were, has, became, had, by, be, being,
# Nearest to by: was, under, through, in, for, be, with, during,
# Nearest to also: which, often, actually, now, still, sometimes, quickly, primarily,
# Nearest to no: any, lexicography, ultima, only, austral, kilmister, triomphe, actually,
# Nearest to or: and, than, gul, passenger, but, shall, rutles, rivaling,
# Nearest to are: were, is, have, those, these, include, although, was,
# Nearest to that: which, however, mah, what, wholesome, this, laude, grievance,
# Nearest to and: or, but, stirrup, including, of, weezer, fiji, in,
# Nearest to new: southwestern, second, bridge, former, midas, kimchi, inherits, hospitals,
# Nearest to during: after, under, at, in, when, from, imposing, of,
# Nearest to american: british, bowling, english, french, precinct, disallow, german, minbari,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to world: insisting, winter, sse, quentin, mahogany, namesake, reign, league,
# Nearest to most: more, less, among, many, some, choi, saturn, several,
# Nearest to used: known, available, referred, responsible, written, published, found, considered,
# Nearest to united: awm, wali, grist, richter, gamemasters, crackdown, urine, burgundians,
# Average loss at step 52000: 3.439980
# Average loss at step 54000: 3.427624
# Average loss at step 56000: 3.437497
# Average loss at step 58000: 3.398539
# Average loss at step 60000: 3.390379
# Nearest to was: is, became, had, has, were, been, be, although,
# Nearest to by: through, be, lifeforms, under, directly, with, tilde, further,
# Nearest to also: now, often, still, actually, sometimes, primarily, which, never,
# Nearest to no: any, triomphe, lexicography, little, analogy, inklings, actually, picket,
# Nearest to or: and, than, dimmer, communions, of, non, mather, weezer,
# Nearest to are: were, is, those, have, these, include, be, including,
# Nearest to that: which, however, what, this, it, mah, there, igg,
# Nearest to and: or, but, fiji, including, although, include, than, circumvent,
# Nearest to new: southwestern, hrer, inherits, midas, cva, rien, winthrop, second,
# Nearest to during: after, under, following, before, in, at, when, although,
# Nearest to american: british, german, precinct, bowling, english, linehan, scottish, french,
# Nearest to five: four, six, three, seven, zero, eight, nine, two,
# Nearest to world: insisting, greeneville, identity, post, winter, barberini, sse, development,
# Nearest to most: more, some, many, among, less, saturn, especially, choi,
# Nearest to used: known, published, responsible, written, referred, available, found, considered,
# Nearest to united: awm, wali, richter, grist, crackdown, gamemasters, overtaking, transfusion,
# Average loss at step 62000: 3.238726
# Average loss at step 64000: 3.256222
# Average loss at step 66000: 3.403158
# Average loss at step 68000: 3.391337
# Average loss at step 70000: 3.355987
# Nearest to was: is, were, has, had, became, been, becomes, does,
# Nearest to by: through, stepping, with, locally, tilde, from, be, polk,
# Nearest to also: now, still, often, which, actually, sometimes, primarily, typically,
# Nearest to no: any, little, triomphe, lexicography, concluded, kilmister, picket, romanticized,
# Nearest to or: and, than, any, communions, looksmart, but, zoning, while,
# Nearest to are: were, is, have, include, although, these, those, contain,
# Nearest to that: which, however, what, this, mah, but, cucumber, fgm,
# Nearest to and: or, but, while, which, appropriation, to, weezer, fiji,
# Nearest to new: southwestern, hrer, midas, fenwick, plated, winthrop, entente, proterozoic,
# Nearest to during: after, before, following, under, until, throughout, at, within,
# Nearest to american: british, english, german, linehan, french, precinct, irish, austrian,
# Nearest to five: four, six, seven, zero, three, eight, nine, two,
# Nearest to world: insisting, post, gear, winter, greeneville, monopolist, vestiges, zoff,
# Nearest to most: more, some, many, less, choi, several, among, all,
# Nearest to used: known, responsible, referred, available, written, seen, published, described,
# Nearest to united: awm, grist, richter, wali, principality, overtaking, crackdown, gunships,
# Average loss at step 72000: 3.370924
# Average loss at step 74000: 3.347131
# Average loss at step 76000: 3.309848
# Average loss at step 78000: 3.346195
# Average loss at step 80000: 3.375893
# Nearest to was: is, became, has, were, had, been, does, being,
# Nearest to by: tilde, under, when, through, and, adjustment, from, titian,
# Nearest to also: now, still, often, actually, which, sometimes, oldsmobile, increasingly,
# Nearest to no: little, any, lexicography, concluded, triomphe, fumimaro, kilmister, freikorps,
# Nearest to or: and, than, but, alus, with, while, skilful, reg,
# Nearest to are: were, include, have, is, although, including, these, those,
# Nearest to that: which, however, mah, where, cosmo, fgm, this, desmond,
# Nearest to and: or, including, but, while, tenochtitlan, clayton, absalom, vigor,
# Nearest to new: fenwick, southwestern, midas, entente, plated, gq, kimchi, distant,
# Nearest to during: after, before, in, when, following, until, despite, throughout,
# Nearest to american: british, french, german, english, irish, disallow, lise, indian,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to world: insisting, truthfulness, zoff, vestiges, montserrat, post, greeneville, winter,
# Nearest to most: more, some, many, less, especially, among, choi, categorical,
# Nearest to used: known, responsible, referred, available, written, published, described, seen,
# Nearest to united: awm, grist, wali, principality, supreme, overtaking, hangover, richter,
# Average loss at step 82000: 3.404286
# Average loss at step 84000: 3.409816
# Average loss at step 86000: 3.386796
# Average loss at step 88000: 3.351560
# Average loss at step 90000: 3.362030
# Nearest to was: is, had, became, were, has, be, been, absorbs,
# Nearest to by: through, under, when, newly, from, stepping, be, with,
# Nearest to also: now, still, often, actually, which, sometimes, who, never,
# Nearest to no: little, any, only, lexicography, concluded, analogy, triomphe, there,
# Nearest to or: and, than, rivaling, but, peleus, bathsheba, though, including,
# Nearest to are: were, is, include, these, have, although, those, contain,
# Nearest to that: which, however, ium, fieldwork, favored, what, but, fgm,
# Nearest to and: or, but, including, while, however, tenochtitlan, unanimity, although,
# Nearest to new: southwestern, particular, fenwick, elkins, entente, gq, midas, tychonoff,
# Nearest to during: after, before, in, under, throughout, through, since, at,
# Nearest to american: british, french, italian, german, israeli, lise, irish, indian,
# Nearest to five: four, seven, eight, six, three, zero, nine, two,
# Nearest to world: insisting, winter, barberini, vestiges, coriolis, greeneville, lal, zoff,
# Nearest to most: more, many, some, choi, less, several, among, all,
# Nearest to used: referred, responsible, known, seen, published, written, available, designed,
# Nearest to united: awm, wali, supreme, grist, visionaries, overtaking, principality, richter,
# Average loss at step 92000: 3.399909
# Average loss at step 94000: 3.249904
# Average loss at step 96000: 3.357595
# Average loss at step 98000: 3.242330
# Average loss at step 100000: 3.355996
# Nearest to was: is, became, has, were, had, been, being, becomes,
# Nearest to by: when, through, without, tilde, including, under, during, from,
# Nearest to also: now, still, actually, never, often, sometimes, which, frequently,
# Nearest to no: any, little, only, concluded, triomphe, analogy, lexicography, precolonial,
# Nearest to or: and, than, bathsheba, rivaling, gul, protectorates, looksmart, antibiotic,
# Nearest to are: were, have, although, these, those, include, while, nos,
# Nearest to that: which, however, what, this, who, where, mah, wholesome,
# Nearest to and: or, but, although, when, while, however, absalom, of,
# Nearest to new: southwestern, subplot, entente, elkins, behind, gq, different, cva,
# Nearest to during: in, after, throughout, since, before, following, despite, until,
# Nearest to american: british, french, english, indian, italian, israeli, australian, austrian,
# Nearest to five: seven, four, six, eight, three, zero, two, nine,
# Nearest to world: insisting, winter, zoff, coriolis, vestiges, truthfulness, lal, roller,
# Nearest to most: more, less, among, choi, especially, many, drexler, particularly,
# Nearest to used: referred, responsible, available, known, seen, designed, written, considered,
# Nearest to united: awm, supreme, overtaking, grist, wali, nation, commonwealth, richter,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, bag_window):
  global data_index
  
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, 2*bag_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:')
print([reverse_dictionary[di] for di in data[:16]])

for bwindow in [1,2]:
  data_index = 0
  batch, labels = generate_batch_cbow(4, bwindow)
  print('\nwith bag_window = %d:' % (bwindow))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
num_sampled = 64 # Number of negative examples to sample.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev= 1.0/ math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset) #(128, 4, 128)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Graph initialized')
  
  average_loss = 0
  loss_cbow = []
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_cbow.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
        
  final_embeddings = normalized_embeddings.eval()
# Out:
# Graph initialized
# Average loss at step 0: 7.997333
# Nearest to during: fe, lambert, sx, fuzzy, impart, ironclad, omphale, pontifex,
# Nearest to five: balaton, roundhouse, duties, dromedary, mcluhan, asdb, unites, redeem,
# Nearest to been: schell, depictions, gundam, potable, novarum, standoff, drummond, linnean,
# Nearest to were: oppenheimer, mexican, oldest, physiol, impeachment, geyser, nurtured, marc,
# Nearest to was: entrails, chimp, ukrainian, kl, prophet, kampen, npd, disgusting,
# Nearest to had: daimler, canada, hotly, homologous, redness, tv, output, backwards,
# Nearest to such: eapc, creeks, ov, pupil, walser, clans, retrieving, domestication,
# Nearest to years: hexen, attorneys, permittivity, laga, sickle, sedans, pius, decode,
# Nearest to eight: oddity, traffic, anticipation, summarised, haaretz, callous, ewe, namo,
# Nearest to new: safavid, iqaluit, drafted, few, anac, stipulation, lime, qazaqstan,
# Nearest to after: catharism, gaza, liberian, closure, physicalism, accelerate, clear, deciphered,
# Nearest to state: overwritten, forensics, vapor, mjf, yen, braveheart, efforts, elegantly,
# Nearest to this: not, donor, jules, compressing, lips, hopping, wilhelm, gaians,
# Nearest to all: hydroxyproline, ripper, code, barr, rushton, zheng, leaves, metroid,
# Nearest to into: dukakis, highs, qui, bowling, undermined, graph, changed, compounding,
# Nearest to his: chick, mugabe, fidelity, pagerank, disgusted, uranus, brunner, metal,
# Average loss at step 2000: 5.120288
# Average loss at step 4000: 4.260436
# Average loss at step 6000: 3.825234
# Average loss at step 8000: 3.633296
# Average loss at step 10000: 3.539784
# Nearest to during: until, teamsters, first, with, against, after, before, aural,
# Nearest to five: four, eight, six, three, seven, zero, nine, two,
# Nearest to been: become, workplaces, universiteit, gundam, siding, harwich, cliffordadams, esc,
# Nearest to were: are, was, had, is, irb, translational, lucius, bard,
# Nearest to was: is, were, had, became, are, morpork, has, info,
# Nearest to had: has, have, having, was, were, signage, rat, overman,
# Nearest to such: well, far, methylation, known, indicate, horsepower, bachelor, ifad,
# Nearest to years: people, ones, pius, zero, consequently, worldcon, hexen, hplc,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to new: treaty, local, rightfully, pipelining, string, overlord, stephen, subscribers,
# Nearest to after: before, in, with, greatness, nashville, borrowers, gallica, controversy,
# Nearest to state: afer, bayonne, ericaceae, widgery, braveheart, episcopalian, musics, neurath,
# Nearest to this: it, which, a, csx, mysia, any, allure, an,
# Nearest to all: many, kassel, bandy, vertebrae, code, stadtbahn, covenants, several,
# Nearest to into: youngsters, zadok, financiers, boss, in, when, dukakis, llc,
# Nearest to his: their, her, its, our, kosrae, my, the, s,
# Average loss at step 12000: 3.550819
# Average loss at step 14000: 3.467549
# Average loss at step 16000: 3.483917
# Average loss at step 18000: 3.424497
# Average loss at step 20000: 3.234863
# Nearest to during: in, through, until, against, before, since, at, after,
# Nearest to five: seven, six, zero, three, four, eight, nine, two,
# Nearest to been: become, occurred, contaminated, physique, were, lucilla, subfields, artois,
# Nearest to were: are, was, is, being, became, quipped, straczynski, have,
# Nearest to was: is, were, became, are, gorbachev, offense, rosario, kipling,
# Nearest to had: has, have, having, mazovia, moldovans, hippos, ladd, was,
# Nearest to such: well, known, ammonites, jekyll, described, far, reworked, sloped,
# Nearest to years: days, months, decades, year, period, centuries, propagated, worldcon,
# Nearest to eight: nine, seven, six, five, zero, three, four, pins,
# Nearest to new: dani, rightfully, playfair, sloppy, democracies, wrecks, ferris, prototyping,
# Nearest to after: before, peculiarity, during, when, widget, for, galvanized, without,
# Nearest to state: musics, champlain, nast, afer, neurath, government, abbess, digweed,
# Nearest to this: which, the, it, that, grad, interquartile, tight, carlisle,
# Nearest to all: various, many, these, marketable, bandy, juanita, both, handguns,
# Nearest to into: through, from, around, youngsters, entrepreneurs, boss, ubu, allosteric,
# Nearest to his: their, its, her, the, s, your, my, our,
# Average loss at step 22000: 3.375599
# Average loss at step 24000: 3.309916
# Average loss at step 26000: 3.264086
# Average loss at step 28000: 3.290852
# Average loss at step 30000: 3.279437
# Nearest to during: after, throughout, before, since, in, despite, until, within,
# Nearest to five: six, seven, zero, eight, four, three, nine, one,
# Nearest to been: become, occurred, come, be, artois, anaerobic, headquartered, sophocles,
# Nearest to were: are, was, is, be, include, being, endeavor, had,
# Nearest to was: is, became, were, becomes, had, did, are, being,
# Nearest to had: has, have, having, was, wrote, could, informing, ladd,
# Nearest to such: well, known, seen, regarded, climbs, result, far, many,
# Nearest to years: days, months, year, decades, centuries, weeks, times, worldcon,
# Nearest to eight: nine, seven, six, zero, five, four, three, th,
# Nearest to new: prototyping, dani, rightfully, declines, dada, adornment, old, ferris,
# Nearest to after: before, during, peculiarity, when, through, since, while, until,
# Nearest to state: government, nast, sommerfeld, champlain, city, skyline, cervantes, afer,
# Nearest to this: which, it, that, another, what, tore, a, the,
# Nearest to all: some, many, both, most, any, every, those, other,
# Nearest to into: through, from, around, berglin, boss, down, pentagram, over,
# Nearest to his: her, their, its, your, the, my, s, lumi,
# Average loss at step 32000: 3.029528
# Average loss at step 34000: 3.227969
# Average loss at step 36000: 3.208514
# Average loss at step 38000: 3.197031
# Average loss at step 40000: 3.168733
# Nearest to during: despite, in, after, throughout, before, within, until, through,
# Nearest to five: seven, six, four, eight, zero, three, nine, two,
# Nearest to been: become, occurred, come, be, physique, artois, sar, gone,
# Nearest to were: are, was, include, is, being, had, became, have,
# Nearest to was: is, became, were, has, makes, becomes, are, remains,
# Nearest to had: has, have, having, could, was, were, ladd, parkland,
# Nearest to such: well, known, regarded, seen, opposed, far, follows, result,
# Nearest to years: months, days, decades, centuries, year, times, minutes, weeks,
# Nearest to eight: seven, six, four, zero, nine, five, three, telnet,
# Nearest to new: ferris, famagusta, carboxylic, lasting, special, different, dani, prototyping,
# Nearest to after: before, during, when, until, through, upon, burrow, since,
# Nearest to state: probabilistic, sliding, soccer, materialistic, merwara, supernova, akhenaten, tertiary,
# Nearest to this: it, which, she, the, another, each, bloodstream, any,
# Nearest to all: many, every, bandy, various, some, juanita, lettres, both,
# Nearest to into: through, within, between, down, around, from, in, over,
# Nearest to his: her, their, its, your, my, our, the, crusading,
# Average loss at step 42000: 3.235858
# Average loss at step 44000: 3.147350
# Average loss at step 46000: 3.138822
# Average loss at step 48000: 3.069506
# Average loss at step 50000: 3.064298
# Nearest to during: throughout, in, since, through, after, within, before, until,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to been: become, occurred, remained, several, come, begun, grown, acrobatic,
# Nearest to were: are, was, being, is, had, be, include, have,
# Nearest to was: is, were, became, being, becomes, are, had, makes,
# Nearest to had: has, have, having, was, can, could, were, ladd,
# Nearest to such: well, follows, known, described, opposed, regarded, seen, just,
# Nearest to years: months, days, year, decades, times, centuries, minutes, weeks,
# Nearest to eight: seven, nine, five, six, zero, three, four, two,
# Nearest to new: prototyping, lasting, different, insolvency, dani, certain, holidays, small,
# Nearest to after: before, during, when, until, following, since, for, without,
# Nearest to state: government, materialistic, champlain, vote, democratic, anglo, esteem, warships,
# Nearest to this: it, which, what, csx, another, asw, rimet, linearly,
# Nearest to all: various, many, some, several, bandy, both, inherits, every,
# Nearest to into: through, from, within, around, in, between, down, under,
# Nearest to his: her, their, its, your, the, my, our, s,
# Average loss at step 52000: 3.101946
# Average loss at step 54000: 3.095477
# Average loss at step 56000: 2.927047
# Average loss at step 58000: 3.033015
# Average loss at step 60000: 3.053795
# Nearest to during: throughout, despite, until, in, after, before, within, at,
# Nearest to five: six, eight, seven, three, four, nine, zero, two,
# Nearest to been: become, occurred, come, remained, evolved, survived, grown, gone,
# Nearest to were: are, was, is, include, had, being, remain, undecidable,
# Nearest to was: is, became, becomes, were, are, had, remained, remains,
# Nearest to had: has, having, have, was, ladd, could, saw, were,
# Nearest to such: well, follows, just, result, regarded, described, seen, opposed,
# Nearest to years: months, days, decades, centuries, times, weeks, minutes, year,
# Nearest to eight: nine, five, six, seven, three, zero, four, two,
# Nearest to new: ferris, prototyping, different, lasting, dani, special, neighboring, overcrowding,
# Nearest to after: before, during, when, following, until, within, informative, without,
# Nearest to state: esteem, configurations, repurchase, merwara, acted, thaw, mps, vote,
# Nearest to this: it, which, another, the, each, attenborough, a, excitation,
# Nearest to all: various, many, some, several, certain, both, always, every,
# Nearest to into: through, within, over, around, via, toward, down, towards,
# Nearest to his: her, their, its, your, s, our, my, the,
# Average loss at step 62000: 3.029415
# Average loss at step 64000: 2.932417
# Average loss at step 66000: 2.951236
# Average loss at step 68000: 2.964947
# Average loss at step 70000: 3.020578
# Nearest to during: in, throughout, after, before, following, at, despite, since,
# Nearest to five: six, three, seven, four, zero, two, eight, coli,
# Nearest to been: become, occurred, grown, appeared, remained, was, evolved, physique,
# Nearest to were: are, was, is, hamito, many, include, been, meitner,
# Nearest to was: is, were, became, becomes, been, remains, has, are,
# Nearest to had: has, have, having, unifil, ladd, was, wrote, ve,
# Nearest to such: well, follows, described, opposed, known, seen, far, served,
# Nearest to years: months, decades, days, minutes, year, centuries, weeks, hours,
# Nearest to eight: nine, six, seven, five, three, zero, two, four,
# Nearest to new: lasting, special, prototyping, ferris, neighboring, sheedy, different, dani,
# Nearest to after: before, during, following, informative, without, when, preceding, afterwards,
# Nearest to state: government, states, mps, veritable, esteem, agronomy, queensland, uncountable,
# Nearest to this: which, another, it, laird, the, what, stagnated, sherbrooke,
# Nearest to all: many, several, various, some, certain, both, numerous, every,
# Nearest to into: through, within, around, across, over, andree, on, from,
# Nearest to his: their, her, your, its, our, s, my, the,
# Average loss at step 72000: 2.953458
# Average loss at step 74000: 2.873935
# Average loss at step 76000: 2.998328
# Average loss at step 78000: 3.016254
# Average loss at step 80000: 2.855664
# Nearest to during: since, throughout, in, after, before, until, when, within,
# Nearest to five: four, seven, six, three, eight, zero, nine, two,
# Nearest to been: become, occurred, grown, appeared, come, evolved, gone, begun,
# Nearest to were: are, was, is, include, be, had, endeavor, christology,
# Nearest to was: is, were, becomes, became, has, are, makes, had,
# Nearest to had: has, have, having, contains, was, could, includes, kor,
# Nearest to such: well, follows, opposed, described, seen, referred, regarded, far,
# Nearest to years: months, decades, days, minutes, year, weeks, centuries, hours,
# Nearest to eight: nine, six, seven, five, four, three, zero, th,
# Nearest to new: prototyping, small, telecast, ferris, dani, gfdl, special, different,
# Nearest to after: before, following, during, when, since, afterwards, until, without,
# Nearest to state: uncountable, government, states, mps, repurchase, zo, configurations, madhya,
# Nearest to this: which, it, another, what, that, rimet, mysia, whatever,
# Nearest to all: some, various, many, every, several, numerous, any, certain,
# Nearest to into: through, across, within, around, down, towards, from, beyond,
# Nearest to his: her, their, your, its, my, our, the, s,
# Average loss at step 82000: 2.940311
# Average loss at step 84000: 2.907517
# Average loss at step 86000: 2.922582
# Average loss at step 88000: 2.954409
# Average loss at step 90000: 2.838314
# Nearest to during: after, in, throughout, before, until, since, at, within,
# Nearest to five: four, six, seven, zero, three, nine, eight, two,
# Nearest to been: become, occurred, fallen, grown, remained, evolved, come, survived,
# Nearest to were: are, was, include, is, had, exist, been, irb,
# Nearest to was: is, were, became, becomes, had, remains, being, provides,
# Nearest to had: has, have, having, was, could, wilfrid, were, gave,
# Nearest to such: well, follows, known, described, seen, far, opposed, result,
# Nearest to years: decades, days, months, minutes, centuries, weeks, year, hours,
# Nearest to eight: seven, nine, six, zero, four, three, five, amalthea,
# Nearest to new: neighboring, special, lasting, dani, previous, old, gfdl, telecast,
# Nearest to after: before, during, when, without, despite, until, upon, following,
# Nearest to state: uncountable, arabica, district, veritable, banner, magnitude, government, aleuts,
# Nearest to this: it, which, another, what, a, whatever, the, that,
# Nearest to all: various, both, many, some, most, certain, multiple, every,
# Nearest to into: through, across, within, onto, beyond, then, via, toward,
# Nearest to his: their, her, its, your, our, my, the, whose,
# Average loss at step 92000: 2.908386
# Average loss at step 94000: 2.898511
# Average loss at step 96000: 2.715813
# Average loss at step 98000: 2.470699
# Average loss at step 100000: 2.719718
# Nearest to during: despite, throughout, after, through, at, until, since, in,
# Nearest to five: three, four, seven, six, eight, zero, two, nine,
# Nearest to been: become, occurred, fallen, grown, come, gone, evolved, survived,
# Nearest to were: are, was, being, is, include, numerous, hamito, had,
# Nearest to was: is, became, were, becomes, remains, are, had, provides,
# Nearest to had: has, have, having, was, ladd, contains, includes, hardship,
# Nearest to such: well, follows, seen, regarded, serve, described, known, far,
# Nearest to years: decades, months, days, minutes, weeks, centuries, year, hours,
# Nearest to eight: nine, six, seven, five, three, four, zero, two,
# Nearest to new: former, gfdl, ferris, old, neighboring, dani, jardine, hittite,
# Nearest to after: before, without, following, during, afterwards, when, despite, since,
# Nearest to state: government, pennsylvania, states, arabica, constitutionally, unrestricted, aberdeen, district,
# Nearest to this: which, another, laird, mentors, some, each, whatever, any,
# Nearest to all: every, both, various, some, many, several, bandy, numerous,
# Nearest to into: through, across, onto, within, beyond, down, toward, towards,
# Nearest to his: their, her, its, your, my, our, s, whose,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
